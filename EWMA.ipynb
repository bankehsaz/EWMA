# %% [markdown]
# <a href="https://colab.research.google.com/github/bankehsaz/EWMA/blob/main/EWMA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import necessary libraries
import numpy as np
import pandas as pd
import plotly.express as px
import yfinance as yf

# %%
# getting data from yahoo finance
df = yf.download(tickers='GLD', start='2020-01-01', end='2024-01-01')
df.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-16  186.580002  186.820007  184.460007  184.869995  184.869995
# 2023-05-17  184.309998  184.449997  183.479996  184.229996  184.229996
# 2023-05-18  182.100006  182.279999  181.339996  181.839996  181.839996
# 2023-05-19  182.250000  184.339996  181.809998  183.639999  183.639999
# 2023-05-22  183.220001  183.839996  182.910004  183.210007  183.210007
#
#              Volume
# Date
# 2023-05-16  9519500
# 2023-05-17  7474300
# 2023-05-18  8812600
# 2023-05-19  8432300
# 2023-05-22  4832300

# %%
# plotting the close price of SPDR Gold Shares (GLD)
px.line(df, x=df.index, y='Close')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Exponentially Weighted Moving Average Calculation
# Is EMA and EWMA the same?
# Wikipedia: Moving average page:
# An Exponential Moving Average (EMA), also known as an Exponentially Weighted Moving Average (EWMA)
df['EWMA-20'] = df['Close'].ewm(span=20).mean()
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-16  186.580002  186.820007  184.460007  184.869995  184.869995
# 2023-05-17  184.309998  184.449997  183.479996  184.229996  184.229996
# 2023-05-18  182.100006  182.279999  181.339996  181.839996  181.839996
# 2023-05-19  182.250000  184.339996  181.809998  183.639999  183.639999
# 2023-05-22  183.220001  183.839996  182.910004  183.210007  183.210007
#
#              Volume     EWMA-20
# Date
# 2023-05-16  9519500  186.576080
# 2023-05-17  7474300  186.352643
# 2023-05-18  8812600  185.922867
# 2023-05-19  8432300  185.705451
# 2023-05-22  4832300  185.467790

# %%
# plotting the close price of SPDR Gold Shares (GLD) with EWMA-20
px.line(df, x=df.index, y=['Close', 'EWMA-20'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Exponentially Weighted Moving Average Calculation
df['EWMA-60'] = df['Close'].ewm(span=60).mean()
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-16  186.580002  186.820007  184.460007  184.869995  184.869995
# 2023-05-17  184.309998  184.449997  183.479996  184.229996  184.229996
# 2023-05-18  182.100006  182.279999  181.339996  181.839996  181.839996
# 2023-05-19  182.250000  184.339996  181.809998  183.639999  183.639999
# 2023-05-22  183.220001  183.839996  182.910004  183.210007  183.210007
#
#              Volume     EWMA-20     EWMA-60
# Date
# 2023-05-16  9519500  186.576080  182.661946
# 2023-05-17  7474300  186.352643  182.713357
# 2023-05-18  8812600  185.922867  182.684723
# 2023-05-19  8432300  185.705451  182.716043
# 2023-05-22  4832300  185.467790  182.732239

# %%
# plotting the close price of SPDR Gold Shares (GLD) with EWMA-20 and EWMA-60
px.line(df, x=df.index, y=['Close', 'EWMA-20', 'EWMA-60'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
